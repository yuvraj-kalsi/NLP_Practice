# %% [markdown]
# # Topic Modeling

# %% [markdown]
# ## Topic Modeling - Attempt #1 (All Text)

# %%
import pandas as pd
import pickle

data = pd.read_pickle('new pickle/dtm_stop.pkl')
data
# Out:
#          aaaaah  aaaaahhhhhhh  aaaaauuugghhhhhh  aaaahhhhh  aaah  aah  \
# ali           0             0                 0          0     0    0
# anthony       0             0                 0          0     0    0
# bill          1             0                 0          0     0    0
# bo            0             1                 1          1     0    0
# dave          0             0                 0          0     1    0
# gabriel       0             0                 0          0     1    0
# hasan         0             0                 0          0     0    0
# jack          0             0                 0          0     0    0
# jim           0             0                 0          0     0    0
# joe           0             0                 0          0     0    0
# john          0             0                 0          0     0    0
# louis         0             0                 0          0     0    3
# ...

# %%
from gensim import matutils, models
import scipy.sparse

# %%
tdm = data.transpose()
tdm.head()
# Out:
#                   ali  anthony  bill  bo  dave  gabriel  hasan  jack  jim  \
# aaaaah              0        0     1   0     0        0      0     0    0
# aaaaahhhhhhh        0        0     0   1     0        0      0     0    0
# aaaaauuugghhhhhh    0        0     0   1     0        0      0     0    0
# aaaahhhhh           0        0     0   1     0        0      0     0    0
# aaah                0        0     0   0     1        1      0     0    0
#
#                   joe  john  louis  mike  ricky  trevor  vir
# aaaaah              0     0      0     0      0       0    0
# aaaaahhhhhhh        0     0      0     0      0       0    0
# aaaaauuugghhhhhh    0     0      0     0      0       0    0
# aaaahhhhh           0     0      0     0      0       0    0
# aaah                0     0      0     0      0       0    0

# %%
sparse_counts = scipy.sparse.csr_matrix(tdm)
corpus = matutils.Sparse2Corpus(sparse_counts)

# %%
cv = pickle.load(open("new pickle/cv_stop.pkl", "rb"))
id2word = dict((v, k) for k, v in cv.vocabulary_.items())
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:288: UserWarning: Trying to unpickle estimator CountVectorizer from version 1.0.2 when using version 1.2.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=2, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.007*"shit" + 0.007*"said" + 0.006*"fucking" + 0.005*"fuck" + 0.005*"hes" + 0.005*"didnt" + 0.005*"want" + 0.005*"life" + 0.005*"theyre" + 0.004*"say"'),
#  (1,
#   '0.008*"said" + 0.006*"fucking" + 0.005*"say" + 0.005*"day" + 0.005*"went" + 0.005*"little" + 0.005*"hes" + 0.004*"want" + 0.004*"cause" + 0.004*"ive"')]

# %%
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=3, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.007*"said" + 0.006*"cause" + 0.006*"fucking" + 0.005*"theyre" + 0.005*"fuck" + 0.005*"life" + 0.005*"theres" + 0.004*"say" + 0.004*"really" + 0.004*"shit"'),
#  (1,
#   '0.009*"fucking" + 0.009*"said" + 0.007*"shit" + 0.005*"went" + 0.005*"day" + 0.005*"say" + 0.005*"didnt" + 0.005*"fuck" + 0.005*"hes" + 0.005*"little"'),
#  (2,
#   '0.006*"said" + 0.006*"want" + 0.006*"hes" + 0.005*"okay" + 0.005*"love" + 0.005*"say" + 0.005*"day" + 0.005*"did" + 0.004*"good" + 0.004*"look"')]

# %%
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=4, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.009*"dad" + 0.006*"want" + 0.005*"love" + 0.005*"shes" + 0.005*"hasan" + 0.005*"say" + 0.004*"mom" + 0.004*"life" + 0.004*"hey" + 0.004*"did"'),
#  (1,
#   '0.008*"fucking" + 0.008*"said" + 0.006*"hes" + 0.006*"fuck" + 0.006*"theyre" + 0.005*"shit" + 0.005*"day" + 0.005*"say" + 0.005*"didnt" + 0.005*"went"'),
#  (2,
#   '0.009*"shit" + 0.006*"fucking" + 0.005*"day" + 0.005*"guys" + 0.005*"did" + 0.004*"want" + 0.004*"say" + 0.004*"okay" + 0.004*"come" + 0.004*"said"'),
#  (3,
#   '0.012*"said" + 0.006*"cause" + 0.005*"want" + 0.005*"look" + 0.004*"say" + 0.004*"tell" + 0.004*"okay" + 0.004*"hes" + 0.004*"says" + 0.004*"good"')]

# %% [markdown]
# ## Topic Modeling - Attempt #2 (Nouns Only)

# %%
from nltk import word_tokenize, pos_tag

def nouns(text):

    is_noun = lambda pos: pos[:2] == 'NN'

    tokenized = word_tokenize(text)

    all_nouns = [word for (word, pos) in pos_tag(tokenized) if is_noun(pos)]

    return ' '.join(all_nouns)

# %%
data_clean = pd.read_pickle('new pickle/data_clean.pkl')
data_clean
# Out:
#                                                 transcript
# ali      ladies and gentlemen please welcome to the sta...
# anthony  thank you thank you thank you san francisco th...
# bill      all right thank you thank you very much thank...
# bo       bo what old macdonald had a farm e i e i o and...
# dave     this is dave he tells dirty jokes for a living...
# gabriel   can you please state your name martin moreno ...
# hasan      whats up davis whats up im home i had to bri...
# jack     look jack jack jack can you sign this for me p...
# jim         ladies and gentlemen please welcome to the ...
# joe         ladies and gentlemen welcome joe rogan  wha...
# john     all right petunia wish me luck out there you w...
# louis    introfade the music out lets roll hold there l...
# mike     wow hey thank you thanks thank you guys hey se...
# ricky    hello hello how you doing great thank you wow ...
# trevor    potatoeszah zah potatoes baby  baby  baby  ca...
# ...

# %%
import pandas as pd
data_nouns = pd.DataFrame(data_clean.transcript.apply(nouns))
data_nouns
# Out:
#                                                 transcript
# ali      ladies gentlemen stage ali hi thank hello na s...
# anthony  thank thank people i em i francisco city world...
# bill     thank thank pleasure georgia area oasis i june...
# bo       macdonald farm e i o farm pig e i i snort macd...
# dave     jokes living stare work profound train thought...
# gabriel  state name martin moreno martinnnnn gabriel ig...
# hasan    whats davis whats home i netflix la york i son...
# jack     jack jack jack – whoa ladies gentlemen stage j...
# jim      ladies gentlemen stage mr jim jefferies thank ...
# joe      ladies gentlemen joe fuck thanks phone fuckfac...
# john     petunia thats hello hello chicago thank crowd ...
# louis    music lets lights lights thank i i place place...
# mike     wow hey thanks look insane years everyone i id...
# ricky    hello thank fuck thank im gon youre weve money...
# trevor   potatoeszah zah potatoes baby house yep yep ye...
# ...

# %%
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer

add_stop_words = ['like', 'im', 'know', 'just', 'dont', 'thats', 'right', 'people',
                  'youre', 'got', 'gonna', 'time', 'think', 'yeah', 'said']
stop_words1 = text.ENGLISH_STOP_WORDS.union(add_stop_words)
stop_words = list(stop_words1)

cvn = CountVectorizer(stop_words=stop_words)
data_cvn = cvn.fit_transform(data_nouns.transcript)
data_dtmn = pd.DataFrame(data_cvn.toarray(), columns=cvn.get_feature_names_out())
data_dtmn.index = data_nouns.index
data_dtmn
# Out:
#          aaaaahhhhhhh  aaaaauuugghhhhhh  aaaahhhhh  aaah  aah  abc  abcs  \
# ali                 0                 0          0     0    0    1     0
# anthony             0                 0          0     0    0    0     0
# bill                0                 0          0     0    0    0     1
# bo                  1                 1          1     0    0    0     0
# dave                0                 0          0     0    0    0     0
# gabriel             0                 0          0     1    0    1     0
# hasan               0                 0          0     0    0    0     0
# jack                0                 0          0     0    0    0     0
# jim                 0                 0          0     0    0    0     0
# joe                 0                 0          0     0    0    0     0
# john                0                 0          0     0    0    0     0
# louis               0                 0          0     0    3    0     0
# ...

# %%
corpusn = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmn.transpose()))

id2wordn = dict((v, k) for k, v in cvn.vocabulary_.items())

# %%
ldan = models.LdaModel(corpus=corpusn, num_topics=2, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.012*"day" + 0.010*"thing" + 0.008*"hes" + 0.008*"man" + 0.006*"life" + 0.006*"way" + 0.006*"shit" + 0.006*"guy" + 0.005*"cause" + 0.005*"gon"'),
#  (1,
#   '0.009*"thing" + 0.007*"day" + 0.007*"life" + 0.007*"hes" + 0.007*"shit" + 0.007*"cause" + 0.007*"way" + 0.006*"man" + 0.006*"lot" + 0.005*"things"')]

# %%
ldan = models.LdaModel(corpus=corpusn, num_topics=3, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.010*"thing" + 0.007*"day" + 0.006*"years" + 0.006*"joke" + 0.005*"hes" + 0.005*"things" + 0.005*"man" + 0.004*"id" + 0.004*"world" + 0.004*"gon"'),
#  (1,
#   '0.011*"day" + 0.010*"thing" + 0.009*"life" + 0.009*"shit" + 0.008*"hes" + 0.008*"man" + 0.008*"cause" + 0.007*"way" + 0.007*"guy" + 0.006*"fuck"'),
#  (2,
#   '0.008*"hes" + 0.007*"way" + 0.006*"thing" + 0.006*"story" + 0.005*"stuff" + 0.005*"bo" + 0.005*"cause" + 0.005*"thank" + 0.005*"okay" + 0.005*"years"')]

# %%
ldan = models.LdaModel(corpus=corpusn, num_topics=4, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.010*"thing" + 0.010*"man" + 0.009*"shit" + 0.009*"life" + 0.008*"hes" + 0.007*"fuck" + 0.007*"way" + 0.007*"things" + 0.006*"day" + 0.006*"gon"'),
#  (1,
#   '0.009*"cause" + 0.007*"point" + 0.006*"thing" + 0.006*"day" + 0.005*"way" + 0.005*"kind" + 0.005*"guy" + 0.005*"id" + 0.004*"bit" + 0.004*"school"'),
#  (2,
#   '0.011*"day" + 0.010*"thing" + 0.008*"hes" + 0.008*"shit" + 0.007*"cause" + 0.007*"way" + 0.006*"life" + 0.006*"shes" + 0.006*"dad" + 0.006*"man"'),
#  (3,
#   '0.016*"day" + 0.012*"hes" + 0.010*"thing" + 0.008*"curry" + 0.008*"man" + 0.007*"life" + 0.007*"order" + 0.005*"food" + 0.005*"friends" + 0.005*"news"')]

# %% [markdown]
# ## Topic Modeling - Attempt #3 (Nouns and Adjectives)

# %%
def nouns_adj(text):

    is_noun_adj = lambda pos: pos[:2] == 'NN' or pos[:2] == 'JJ'

    tokenized = word_tokenize(text)

    nouns_adj = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj(pos)] 
    
    return ' '.join(nouns_adj)

# %%
data_nouns_adj = pd.DataFrame(data_clean.transcript.apply(nouns_adj))
data_nouns_adj
# Out:
#                                                 transcript
# ali      ladies gentlemen welcome stage ali wong hi wel...
# anthony  thank san francisco thank good people surprise...
# bill     right thank thank pleasure greater atlanta geo...
# bo       old macdonald farm e i i o farm pig e i i snor...
# dave     dirty jokes living stare most hard work profou...
# gabriel  state name martin moreno martinnnnn gabriel ig...
# hasan    whats davis whats im home i netflix special la...
# jack     jack jack jack jack– – whoa whoa whoa ladies g...
# jim      ladies gentlemen welcome stage mr jim jefferie...
# joe      ladies gentlemen joe fuck san francisco thanks...
# john     right petunia august thats good right hello he...
# louis    music lets lights lights thank much i i i nice...
# mike     wow hey thanks hey seattle nice look crazy ins...
# ricky    hello great thank fuck thank lovely welcome im...
# trevor   potatoeszah zah potatoes baby house second yep...
# ...

# %%
cvna = CountVectorizer(stop_words=stop_words, max_df=.8)
data_cvna = cvna.fit_transform(data_nouns_adj.transcript)
data_dtmna = pd.DataFrame(data_cvna.toarray(), columns=cvna.get_feature_names_out())
data_dtmna.index = data_nouns_adj.index
data_dtmna
# Out:
#          aaaaah  aaaaahhhhhhh  aaaaauuugghhhhhh  aaaahhhhh  aaah  aah  abc  \
# ali           0             0                 0          0     0    0    1
# anthony       0             0                 0          0     0    0    0
# bill          1             0                 0          0     0    0    0
# bo            0             1                 1          1     0    0    0
# dave          0             0                 0          0     0    0    0
# gabriel       0             0                 0          0     1    0    1
# hasan         0             0                 0          0     0    0    0
# jack          0             0                 0          0     0    0    0
# jim           0             0                 0          0     0    0    0
# joe           0             0                 0          0     0    0    0
# john          0             0                 0          0     0    0    0
# ...

# %%
corpusna = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmna.transpose()))

id2wordna = dict((v, k) for k, v in cvna.vocabulary_.items())

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=2, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.006*"fuck" + 0.004*"black" + 0.003*"men" + 0.003*"joke" + 0.002*"ass" + 0.002*"jenny" + 0.002*"son" + 0.002*"guns" + 0.002*"ahah" + 0.002*"husband"'),
#  (1,
#   '0.006*"fuck" + 0.004*"mom" + 0.003*"dude" + 0.003*"indian" + 0.003*"joke" + 0.003*"parents" + 0.003*"food" + 0.002*"comedy" + 0.002*"fact" + 0.002*"dog"')]

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.009*"fuck" + 0.005*"mom" + 0.004*"dude" + 0.004*"parents" + 0.003*"indian" + 0.003*"joke" + 0.003*"black" + 0.003*"wife" + 0.002*"mad" + 0.002*"curry"'),
#  (1,
#   '0.005*"fuck" + 0.004*"joke" + 0.003*"bo" + 0.003*"repeat" + 0.003*"eye" + 0.003*"dog" + 0.003*"ass" + 0.003*"guns" + 0.003*"jokes" + 0.003*"water"'),
#  (2,
#   '0.005*"er" + 0.003*"mom" + 0.003*"country" + 0.003*"dogs" + 0.003*"mexican" + 0.003*"fact" + 0.003*"martin" + 0.003*"husband" + 0.003*"fckin" + 0.003*"dude"')]

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.005*"joke" + 0.005*"mom" + 0.005*"er" + 0.004*"fuck" + 0.004*"clinton" + 0.004*"guns" + 0.004*"ass" + 0.004*"girlfriend" + 0.003*"anthony" + 0.003*"wife"'),
#  (1,
#   '0.008*"fuck" + 0.004*"dude" + 0.004*"ok" + 0.004*"bo" + 0.003*"jenny" + 0.003*"eye" + 0.003*"repeat" + 0.003*"men" + 0.003*"water" + 0.003*"contact"'),
#  (2,
#   '0.005*"indian" + 0.005*"joke" + 0.005*"fuck" + 0.004*"curry" + 0.004*"dude" + 0.003*"food" + 0.003*"order" + 0.003*"hell" + 0.003*"normal" + 0.003*"news"'),
#  (3,
#   '0.005*"fuck" + 0.005*"mom" + 0.004*"black" + 0.004*"son" + 0.004*"hasan" + 0.004*"ahah" + 0.004*"comedy" + 0.003*"martin" + 0.003*"country" + 0.003*"dogs"')]

# %% [markdown]
# ## Identify Topics in Each Document

# %% [markdown]
# ### Topics Name

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=80)
ldana.print_topics()
# Out:
# [(0,
#   '0.007*"indian" + 0.005*"bo" + 0.005*"curry" + 0.005*"jenny" + 0.005*"order" + 0.004*"repeat" + 0.004*"eye" + 0.004*"contact" + 0.003*"andy" + 0.003*"comedy"'),
#  (1,
#   '0.006*"mom" + 0.005*"er" + 0.005*"fuck" + 0.004*"parents" + 0.004*"clinton" + 0.004*"hasan" + 0.003*"girlfriend" + 0.003*"ass" + 0.003*"guns" + 0.003*"class"'),
#  (2,
#   '0.005*"joke" + 0.004*"dogs" + 0.003*"fact" + 0.003*"martin" + 0.003*"voice" + 0.003*"jokes" + 0.003*"twitter" + 0.003*"tweet" + 0.003*"mexican" + 0.002*"nuts"'),
#  (3,
#   '0.013*"fuck" + 0.007*"dude" + 0.004*"black" + 0.004*"joke" + 0.003*"men" + 0.003*"ok" + 0.003*"mad" + 0.003*"mom" + 0.003*"water" + 0.003*"dick"')]

# %% [markdown]
# * Topic 0: mom, indian
# * Topic 1: parents, wife
# * Topic 2: profanity
# * Topic 3: guns

# %% [markdown]
# ### Topics Name along with comedians

# %%
corpus_transformed = ldana[corpusna]
list(zip([a for [(a,b)] in corpus_transformed], data_dtmna.index))
# Out:
# [(3, 'ali'),
#  (3, 'anthony'),
#  (3, 'bill'),
#  (0, 'bo'),
#  (3, 'dave'),
#  (2, 'gabriel'),
#  (1, 'hasan'),
#  (2, 'jack'),
#  (1, 'jim'),
#  (3, 'joe'),
#  (1, 'john'),
#  (3, 'louis'),
#  (0, 'mike'),
#  (2, 'ricky'),
#  (0, 'trevor'),
#  (1, 'vir')]

# %% [markdown]
# * Topic 0: mom, indian [Ali, Gabriel, Louis, Trevor]
# * Topic 1: husband, wife [John, Mike, Vir]
# * Topic 2: profanity [Bo, Dave, Jack, Joe]
# * Topic 3: guns [Anthony, Bill, Hasan, Jim, Ricky]

# %% [markdown]
# ## Changing Parameters

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=5, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.007*"mom" + 0.006*"joke" + 0.006*"indian" + 0.004*"curry" + 0.004*"clinton" + 0.004*"order" + 0.004*"voice" + 0.004*"fact" + 0.003*"news" + 0.003*"anthony"'),
#  (1,
#   '0.005*"bo" + 0.005*"jenny" + 0.005*"repeat" + 0.004*"eye" + 0.004*"contact" + 0.003*"sad" + 0.003*"hotel" + 0.003*"andy" + 0.003*"comedy" + 0.003*"cos"'),
#  (2,
#   '0.017*"fuck" + 0.009*"dude" + 0.005*"black" + 0.004*"ahah" + 0.004*"water" + 0.004*"men" + 0.004*"gay" + 0.004*"dick" + 0.003*"son" + 0.003*"religion"'),
#  (3,
#   '0.005*"er" + 0.005*"ok" + 0.005*"joke" + 0.004*"food" + 0.003*"somebody" + 0.003*"tit" + 0.003*"nuts" + 0.003*"husband" + 0.003*"fckin" + 0.003*"older"'),
#  (4,
#   '0.008*"fuck" + 0.006*"hasan" + 0.005*"guns" + 0.005*"mom" + 0.004*"class" + 0.004*"ass" + 0.004*"parents" + 0.004*"brown" + 0.004*"son" + 0.004*"men"')]

# %% [markdown]
# ### Topics Name

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=5, id2word=id2wordna, passes=80)
ldana.print_topics()
# Out:
# [(0,
#   '0.009*"fuck" + 0.006*"dude" + 0.004*"ass" + 0.004*"mom" + 0.004*"gun" + 0.004*"ok" + 0.003*"hasan" + 0.003*"guns" + 0.003*"son" + 0.003*"men"'),
#  (1,
#   '0.006*"black" + 0.005*"ahah" + 0.005*"son" + 0.005*"fuck" + 0.005*"martin" + 0.004*"dogs" + 0.004*"fact" + 0.004*"mexican" + 0.004*"nigga" + 0.004*"kevin"'),
#  (2,
#   '0.007*"fuck" + 0.005*"er" + 0.004*"mom" + 0.004*"joke" + 0.004*"clinton" + 0.003*"water" + 0.003*"parents" + 0.003*"food" + 0.003*"wife" + 0.003*"cow"'),
#  (3,
#   '0.008*"indian" + 0.006*"bo" + 0.005*"curry" + 0.005*"jenny" + 0.005*"order" + 0.005*"repeat" + 0.004*"eye" + 0.004*"contact" + 0.004*"andy" + 0.003*"comedy"'),
#  (4,
#   '0.009*"joke" + 0.006*"anthony" + 0.005*"jokes" + 0.004*"grandma" + 0.004*"milk" + 0.004*"mom" + 0.004*"shark" + 0.004*"mad" + 0.003*"jack" + 0.003*"today"')]

# %% [markdown]
# * Topic 0: food, hotel
# * Topic 1: indian, news
# * Topic 2: profanity
# * Topic 3: guns
# * Topic 5: husband, mom

# %% [markdown]
# ### Topics Name along with comedians

# %%
corpus_transformed = ldana[corpusna]
list(zip([a for [(a,b)] in corpus_transformed], data_dtmna.index))
# Out:
# [(0, 'ali'),
#  (4, 'anthony'),
#  (0, 'bill'),
#  (3, 'bo'),
#  (1, 'dave'),
#  (1, 'gabriel'),
#  (0, 'hasan'),
#  (4, 'jack'),
#  (0, 'jim'),
#  (2, 'joe'),
#  (2, 'john'),
#  (0, 'louis'),
#  (3, 'mike'),
#  (2, 'ricky'),
#  (3, 'trevor'),
#  (2, 'vir')]

# %% [markdown]
# * Topic 0: mom, indian [Ali, Gabriel, Louis, Trevor]
# * Topic 1: indian, news [ Louis, Trevor]
# * Topic 2: profanity [Anthony, Bo, Gabriel, Ricky, ,Jack, Joe]
# * Topic 3: guns [Bill, Jim, John, Mike]
# * Topic 4: husband, mom [ Ali ]

# %% [markdown]
# ## Topic Modeling - Attempt #4 (Nouns and Verbs)

# %%
def nouns_verb(text):

    is_noun_verb = lambda pos: pos[:2] == 'NN' or pos[:2] == 'VB'

    tokenized = word_tokenize(text)

    nouns_verb = [word for (word, pos) in pos_tag(tokenized) if is_noun_verb(pos)] 
    
    return ' '.join(nouns_verb)

# %%
data_nouns_verb = pd.DataFrame(data_clean.transcript.apply(nouns_verb))
data_nouns_verb
# Out:
#                                                 transcript
# ali      ladies gentlemen please stage ali hi hello tha...
# anthony  thank thank thank thank be people were i told ...
# bill     thank thank thank thank are whats going thank ...
# bo       bo macdonald had farm e i e o farm had pig e i...
# dave     is dave tells jokes living stare is work happe...
# gabriel  please state name martin moreno know martinnnn...
# hasan    whats davis whats home i had bring netflix sai...
# jack     look jack jack jack sign please – whoa whoa st...
# jim      ladies gentlemen please stage mr jim jefferies...
# joe      ladies gentlemen welcome joe rogan fuck is goi...
# john     petunia wish die thats hello hello chicago see...
# louis    introfade music lets roll hold lights do light...
# mike     wow hey thank thanks thank guys see look look ...
# ricky    hello hello doing thank wow calm shut fuck tha...
# trevor   potatoeszah zah potatoes baby baby i hear hous...
# ...

# %%
cvna = CountVectorizer(stop_words=stop_words, max_df=.8)
data_cvna = cvna.fit_transform(data_nouns_verb.transcript)
data_dtmna = pd.DataFrame(data_cvna.toarray(), columns=cvna.get_feature_names_out())
data_dtmna.index = data_nouns_verb.index
data_dtmna
# Out:
#          aaaaahhhhhhh  aaaaauuugghhhhhh  aaaahhhhh  aaah  aah  abandon  abc  \
# ali                 0                 0          0     0    0        0    1
# anthony             0                 0          0     0    0        0    0
# bill                0                 0          0     0    0        0    0
# bo                  1                 1          1     0    0        0    0
# dave                0                 0          0     1    0        0    0
# gabriel             0                 0          0     1    0        0    1
# hasan               0                 0          0     0    0        0    0
# jack                0                 0          0     0    0        0    0
# jim                 0                 0          0     0    0        0    0
# joe                 0                 0          0     0    0        0    0
# john                0                 0          0     0    0        0    0
# ...

# %%
corpusna = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmna.transpose()))

id2wordna = dict((v, k) for k, v in cvna.vocabulary_.items())

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=2, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.005*"mom" + 0.004*"dude" + 0.003*"parents" + 0.002*"wife" + 0.002*"clinton" + 0.002*"er" + 0.002*"country" + 0.002*"son" + 0.002*"hit" + 0.002*"walked"'),
#  (1,
#   '0.004*"joke" + 0.003*"wan" + 0.003*"men" + 0.002*"ass" + 0.002*"dude" + 0.002*"jokes" + 0.002*"water" + 0.002*"hed" + 0.002*"uh" + 0.002*"mom"')]

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.006*"mom" + 0.003*"parents" + 0.003*"joke" + 0.003*"son" + 0.003*"men" + 0.003*"clinton" + 0.003*"ass" + 0.003*"wan" + 0.003*"walked" + 0.003*"guns"'),
#  (1,
#   '0.005*"dude" + 0.002*"fact" + 0.002*"dog" + 0.002*"living" + 0.002*"hit" + 0.002*"idea" + 0.002*"sleep" + 0.002*"minutes" + 0.002*"mom" + 0.002*"dogs"'),
#  (2,
#   '0.005*"joke" + 0.004*"hed" + 0.004*"er" + 0.004*"food" + 0.004*"bo" + 0.003*"repeat" + 0.003*"curry" + 0.003*"eye" + 0.003*"news" + 0.003*"order"')]

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.003*"dog" + 0.003*"ass" + 0.002*"men" + 0.002*"fact" + 0.002*"repeat" + 0.002*"bo" + 0.002*"guns" + 0.002*"eye" + 0.002*"dude" + 0.002*"wan"'),
#  (1,
#   '0.006*"joke" + 0.005*"curry" + 0.004*"ahah" + 0.003*"order" + 0.003*"trevor" + 0.003*"news" + 0.003*"walked" + 0.003*"forget" + 0.003*"anthony" + 0.003*"jokes"'),
#  (2,
#   '0.006*"dude" + 0.005*"joke" + 0.005*"er" + 0.003*"hell" + 0.003*"hed" + 0.003*"sleep" + 0.003*"bring" + 0.003*"somebody" + 0.003*"nuts" + 0.003*"gun"'),
#  (3,
#   '0.008*"mom" + 0.005*"parents" + 0.005*"clinton" + 0.003*"wan" + 0.003*"husband" + 0.003*"dude" + 0.003*"york" + 0.003*"cow" + 0.003*"wife" + 0.002*"bike"')]

# %% [markdown]
# ### Topics Name

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=80)
ldana.print_topics()
# Out:
# [(0,
#   '0.006*"dude" + 0.004*"joke" + 0.003*"fact" + 0.003*"dogs" + 0.003*"dog" + 0.003*"water" + 0.002*"sleep" + 0.002*"hell" + 0.002*"shot" + 0.002*"hed"'),
#  (1,
#   '0.003*"mom" + 0.003*"bo" + 0.003*"repeat" + 0.003*"parents" + 0.003*"guns" + 0.003*"men" + 0.003*"wan" + 0.003*"uh" + 0.003*"ass" + 0.003*"class"'),
#  (2,
#   '0.007*"er" + 0.004*"fck" + 0.003*"somebody" + 0.003*"milk" + 0.003*"food" + 0.003*"girlfriend" + 0.003*"hotel" + 0.003*"jack" + 0.003*"sign" + 0.003*"erm"'),
#  (3,
#   '0.005*"joke" + 0.005*"mom" + 0.004*"clinton" + 0.004*"walked" + 0.004*"curry" + 0.004*"ahah" + 0.003*"wife" + 0.003*"parents" + 0.003*"order" + 0.003*"hed"')]

# %% [markdown]
# * Topic 0: mom, parents
# * Topic 1: men, husband
# * Topic 2: wife, food
# * Topic 3: newsm, fact

# %% [markdown]
# ### Topics Name along with comedians

# %%
corpus_transformed = ldana[corpusna]
list(zip([a for [(a,b)] in corpus_transformed], data_dtmna.index))
# Out:
# [(1, 'ali'),
#  (3, 'anthony'),
#  (0, 'bill'),
#  (1, 'bo'),
#  (3, 'dave'),
#  (0, 'gabriel'),
#  (1, 'hasan'),
#  (2, 'jack'),
#  (1, 'jim'),
#  (0, 'joe'),
#  (3, 'john'),
#  (0, 'louis'),
#  (1, 'mike'),
#  (0, 'ricky'),
#  (3, 'trevor'),
#  (2, 'vir')]

# %% [markdown]
# * Topic 0: mom, parents [Anthony, Hasan, Jim, Mike]
# * Topic 1: men, husband [Ali, Bill, Dave, Joe, Louis]
# * Topic 2: wife, food [Bo, Jack, John, Vir]
# * Topic 3: news, fact [Gabriel, Ricky, Trevor]

# %% [markdown]
# ## Topic Modeling - Attempt #5 (Nouns and Adverbs)

# %%
def nouns_adverb(text):

    is_noun_adverb = lambda pos: pos[:2] == 'NN' or pos[:2] == 'RB'

    tokenized = word_tokenize(text)

    nouns_adverb = [word for (word, pos) in pos_tag(tokenized) if is_noun_adverb(pos)] 
    
    return ' '.join(nouns_adverb)

# %%
data_nouns_adverb = pd.DataFrame(data_clean.transcript.apply(nouns_adverb))
data_nouns_adverb
# Out:
#                                                 transcript
# ali      ladies gentlemen stage ali hi thank hello na s...
# anthony  thank thank so much so here people i em i fran...
# bill     thank very much thank pleasure here georgia ar...
# bo       macdonald farm e i o farm pig e i i here snort...
# dave     jokes living stare work profound train thought...
# gabriel  state name martin moreno martinnnnn gabriel ig...
# hasan    whats davis whats home i back here netflix la ...
# jack     jack jack jack – whoa back ladies gentlemen st...
# jim      ladies gentlemen stage mr jim jefferies thank ...
# joe      ladies gentlemen joe fuck thanks phone fuckfac...
# john     petunia there thats pretty hello hello chicago...
# louis    music lets lights lights thank very i i necess...
# mike     wow hey thanks look here insane so years ago p...
# ricky    hello thank fuck thank im gon youre weve money...
# trevor   potatoeszah zah potatoes baby house yep yep ye...
# ...

# %%
cvna = CountVectorizer(stop_words=stop_words, max_df=.8)
data_cvna = cvna.fit_transform(data_nouns_adverb.transcript)
data_dtmna = pd.DataFrame(data_cvna.toarray(), columns=cvna.get_feature_names_out())
data_dtmna.index = data_nouns_adverb.index
data_dtmna
# Out:
#          aaaaahhhhhhh  aaaaauuugghhhhhh  aaaahhhhh  aaah  aah  abc  abcs  \
# ali                 0                 0          0     0    0    1     0
# anthony             0                 0          0     0    0    0     0
# bill                0                 0          0     0    0    0     1
# bo                  1                 1          1     0    0    0     0
# dave                0                 0          0     0    0    0     0
# gabriel             0                 0          0     1    0    1     0
# hasan               0                 0          0     0    0    0     0
# jack                0                 0          0     0    0    0     0
# jim                 0                 0          0     0    0    0     0
# joe                 0                 0          0     0    0    0     0
# john                0                 0          0     0    0    0     0
# louis               0                 0          0     0    3    0     0
# ...

# %%
corpusna = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmna.transpose()))

id2wordna = dict((v, k) for k, v in cvna.vocabulary_.items())

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=2, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.007*"fuck" + 0.006*"joke" + 0.004*"mom" + 0.004*"comedy" + 0.003*"jokes" + 0.003*"fucking" + 0.003*"ass" + 0.003*"fact" + 0.003*"son" + 0.003*"ta"'),
#  (1,
#   '0.005*"fuck" + 0.004*"dude" + 0.003*"mom" + 0.003*"wife" + 0.003*"parents" + 0.003*"food" + 0.003*"fucking" + 0.002*"clinton" + 0.002*"order" + 0.002*"idea"')]

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.006*"fuck" + 0.005*"joke" + 0.005*"dude" + 0.004*"food" + 0.004*"fucking" + 0.003*"gun" + 0.003*"ass" + 0.003*"mom" + 0.003*"men" + 0.003*"guns"'),
#  (1,
#   '0.008*"fuck" + 0.004*"wife" + 0.004*"mom" + 0.004*"parents" + 0.003*"clinton" + 0.003*"men" + 0.003*"fucking" + 0.003*"water" + 0.003*"dude" + 0.003*"president"'),
#  (2,
#   '0.005*"joke" + 0.005*"mom" + 0.004*"dogs" + 0.004*"comedy" + 0.003*"voice" + 0.003*"fact" + 0.003*"parents" + 0.003*"country" + 0.003*"martin" + 0.003*"fuck"')]

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.012*"fuck" + 0.006*"fucking" + 0.006*"dude" + 0.005*"son" + 0.004*"gun" + 0.004*"men" + 0.004*"guns" + 0.004*"class" + 0.003*"ass" + 0.003*"mom"'),
#  (1,
#   '0.008*"joke" + 0.006*"mom" + 0.004*"food" + 0.004*"news" + 0.004*"fact" + 0.004*"parents" + 0.004*"dogs" + 0.003*"voice" + 0.003*"jokes" + 0.003*"dog"'),
#  (2,
#   '0.009*"fuck" + 0.006*"dude" + 0.005*"ta" + 0.005*"er" + 0.004*"husband" + 0.004*"mom" + 0.004*"men" + 0.004*"somebody" + 0.004*"ass" + 0.003*"body"'),
#  (3,
#   '0.005*"bo" + 0.004*"eye" + 0.004*"repeat" + 0.004*"hotel" + 0.004*"jenny" + 0.004*"contact" + 0.003*"accident" + 0.003*"pretty" + 0.003*"milk" + 0.003*"end"')]

# %% [markdown]
# ### Topics Name

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=5, id2word=id2wordna, passes=80)
ldana.print_topics()
# Out:
# [(0,
#   '0.008*"fuck" + 0.006*"dude" + 0.004*"comedy" + 0.004*"love" + 0.004*"parents" + 0.004*"mom" + 0.003*"fucking" + 0.003*"bo" + 0.003*"repeat" + 0.003*"men"'),
#  (1,
#   '0.007*"fuck" + 0.005*"fact" + 0.004*"mom" + 0.004*"dude" + 0.004*"dogs" + 0.004*"er" + 0.004*"ta" + 0.004*"martin" + 0.004*"country" + 0.003*"voice"'),
#  (2,
#   '0.006*"joke" + 0.006*"fuck" + 0.005*"food" + 0.004*"guns" + 0.004*"fucking" + 0.004*"curry" + 0.004*"child" + 0.004*"men" + 0.004*"ass" + 0.003*"order"'),
#  (3,
#   '0.008*"joke" + 0.007*"clinton" + 0.006*"mom" + 0.005*"cow" + 0.005*"wife" + 0.004*"parents" + 0.004*"nuts" + 0.004*"jenner" + 0.004*"chimp" + 0.003*"boy"'),
#  (4,
#   '0.000*"fuck" + 0.000*"mom" + 0.000*"dude" + 0.000*"parents" + 0.000*"food" + 0.000*"joke" + 0.000*"months" + 0.000*"ass" + 0.000*"men" + 0.000*"morning"')]

# %% [markdown]
# * Topic 0: food, milk
# * Topic 1: profanity
# * Topic 2: parents, jokes
# * Topic 3: mom, wife
# * Topic 4: men, birthday

# %% [markdown]
# ### Topics Name along with the comedians

# %%
corpus_transformed = ldana[corpusna]
list(zip([a for [(a,b)] in corpus_transformed], data_dtmna.index))
# Out:
# [(0, 'ali'),
#  (2, 'anthony'),
#  (0, 'bill'),
#  (0, 'bo'),
#  (0, 'dave'),
#  (1, 'gabriel'),
#  (0, 'hasan'),
#  (2, 'jack'),
#  (2, 'jim'),
#  (1, 'joe'),
#  (3, 'john'),
#  (2, 'louis'),
#  (0, 'mike'),
#  (3, 'ricky'),
#  (2, 'trevor'),
#  (1, 'vir')]

# %% [markdown]
# * Topic 0: food, milk [Jack, Louis, Vir]
# * Topic 1: profanity [Bill, Bo, Gabriel, Jim,]
# * Topic 2: parents, jokes [Anthony, Dave, Mike, Ricky]
# * Topic 3: mom, wife [Ali, John, Trevor]
# * Topic 4: men, birthday [Hasan, Joe]
